# %% [markdown]
# Лабораторная работа по теме "Реализация алгоритма линейной регрессии на Python"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_scores.csv")

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# Ниже представлена статистическая информация о используемых данных

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.plot(x = 'Hours', y = 'Scores', style = 'o')
plt.title('Зависимость оценки от количества часов')
plt.xlabel('Часы') 
plt.ylabel('Оценка') 
plt.show()

# %%
mx = x.sum()/n
my = y.sum()/n
a2 = np.dot(x.T, x)/n
a11 = np.dot(x.T, y)/n

# %%
k = (a11-mx*my)/(a2-mx**2)
b = my - k*mx
print(f"k = {k}, b = {b}")
# Out:
# k = 9.775803390787468, b = 2.48367340537321

# %%
f = [k*x+b for x in range(11)]
plt.plot(f, 'green')
plt.scatter(x, y)
plt.xlabel('Часы') 
plt.ylabel('Оценка')
# Out:
# Text(0, 0.5, 'Оценка')

# %%
plt.scatter(x, y)
plt.title('Квадрат ошибок')
plt.plot(f, 'green')
plt.xlabel('Часы') 
plt.ylabel('Оценка') 
for xi, yi in zip(x, y):
    yi_pred = k * xi + b
    plt.plot([xi, xi], [yi, yi_pred], color='red', linestyle='--')
    plt.fill_betweenx([yi, yi_pred], xi - 0.1, xi + 0.1, color='red', alpha=0.3)
plt.show()

# %% [markdown]
# Вывод всех трех изображений

# %%
plt.scatter(x, y)
plt.title('Зависимость оценки от количества часов')
plt.xlabel('Часы') 
plt.ylabel('Оценка') 
plt.show()

plt.title("Линейная регрессия")
plt.plot(f, 'green')
plt.xlabel('Часы') 
plt.ylabel('Оценка') 
plt.show()

plt.scatter(x, y)
plt.plot(f, 'green')
plt.title('Зависимость оценки от количества часов')
plt.xlabel('Часы') 
plt.ylabel('Оценка') 
plt.show()
